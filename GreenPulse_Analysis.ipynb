# %% [markdown]
# **GreenPulse Climate Analysis**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cab20754-453a-4a64-973b-117e22b1376d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cab20754-453a-4a64-973b-117e22b1376d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sna

# %% [markdown]
# **Read Dataset**

# %%
df = pd.read_excel("GreenPulse.csv.xlsx")
df
# Out:
#      Year    Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 0    2006         UK                    8.9                          9.3
# 1    2019        USA                   31.0                          4.8
# 2    2014     France                   33.9                          2.8
# 3    2010  Argentina                    5.9                          1.8
# 4    2007    Germany                   26.9                          5.6
# ..    ...        ...                    ...                          ...
# 995  2019      India                   23.6                          8.0
# 996  2000         UK                   21.8                         10.0
# 997  2019  Argentina                   23.8                          8.9
# 998  2016  Australia                   21.0                         14.9
# 999  2011    Germany                   24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %% [markdown]
# **Apply Basic Functions**

# %%
df.head()
# Out:
#    Year    Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 0  2006         UK                    8.9                          9.3
# 1  2019        USA                   31.0                          4.8
# 2  2014     France                   33.9                          2.8
# 3  2010  Argentina                    5.9                          1.8
# 4  2007    Germany                   26.9                          5.6
#
#    Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 0                  3.1           1441   530911230                  20.4
# 1                  4.2           2407   107364344                  49.2
# 2                  2.2           1241   441101758                  33.3
# 3                  3.2           1892  1069669579                  23.7
# 4                  2.4           1743   124079175                  12.5
#
#    Extreme Weather Events  Forest Area (%)
# 0                      14             59.8
# ...

# %%
df.tail()
# Out:
#      Year    Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 995  2019      India                   23.6                          8.0
# 996  2000         UK                   21.8                         10.0
# 997  2019  Argentina                   23.8                          8.9
# 998  2016  Australia                   21.0                         14.9
# 999  2011    Germany                   24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 995                  1.2           1365  1358019778                  10.0
# 996                  2.2           1273   876123161                  14.9
# 997                  4.7            891  1120533308                  25.9
# 998                  3.1           1136   380662109                  24.5
# 999                  2.1           2854   398407112                  41.0
#
#      Extreme Weather Events  Forest Area (%)
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Avg Temperature (Â°C)',
#        'CO2 Emissions (Tons/Capita)', 'Sea Level Rise (mm)', 'Rainfall (mm)',
#        'Population', 'Renewable Energy (%)', 'Extreme Weather Events',
#        'Forest Area (%)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1000 non-null   int64
#  1   Country                      1000 non-null   object
#  2   Avg Temperature (Â°C)        1000 non-null   float64
#  3   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  4   Sea Level Rise (mm)          1000 non-null   float64
#  5   Rainfall (mm)                1000 non-null   int64
#  6   Population                   1000 non-null   int64
#  7   Renewable Energy (%)         1000 non-null   float64
#  8   Extreme Weather Events       1000 non-null   int64
#  9   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#               Year  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# count  1000.000000            1000.000000                  1000.000000
# mean   2011.432000              19.883100                    10.425800
# std       7.147199               8.542897                     5.614665
# min    2000.000000               5.000000                     0.500000
# 25%    2005.000000              12.175000                     5.575000
# 50%    2012.000000              20.100000                    10.700000
# 75%    2018.000000              27.225000                    15.400000
# max    2023.000000              34.900000                    20.000000
#
#        Sea Level Rise (mm)  Rainfall (mm)    Population  Renewable Energy (%)  \
# count          1000.000000    1000.000000  1.000000e+03           1000.000000
# mean              3.009600    1738.761000  7.053830e+08             27.300500
# std               1.146081     708.976616  4.093910e+08             12.970808
# ...

# %%
df.sample(2)
# Out:
#      Year Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 867  2011  Brazil                   29.0                          1.5
# 538  2017      UK                    6.3                         11.0
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 867                  3.6           2471   959148511                   7.8
# 538                  4.8            886  1193832295                  23.8
#
#      Extreme Weather Events  Forest Area (%)
# 867                      13             62.5
# 538                      13             35.0

# %%
df.dtypes
# Out:
# Year                             int64
# Country                         object
# Avg Temperature (Â°C)          float64
# CO2 Emissions (Tons/Capita)    float64
# Sea Level Rise (mm)            float64
# Rainfall (mm)                    int64
# Population                       int64
# Renewable Energy (%)           float64
# Extreme Weather Events           int64
# Forest Area (%)                float64
# dtype: object

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# Year                           0
# Country                        0
# Avg Temperature (Â°C)          0
# CO2 Emissions (Tons/Capita)    0
# Sea Level Rise (mm)            0
# Rainfall (mm)                  0
# Population                     0
# Renewable Energy (%)           0
# Extreme Weather Events         0
# Forest Area (%)                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Remove Missing Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# Check Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Remove Duplicates

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# **Data Filtering**

# %% [markdown]
# Country = India

# %%
df[df["Country"]=="India"]
# Out:
#      Year Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 15   2023   India                   31.0                         17.6
# 22   2005   India                    7.7                          6.1
# 25   2000   India                   20.9                         15.9
# 46   2003   India                   18.9                         19.0
# 52   2019   India                   27.7                          5.1
# ..    ...     ...                    ...                          ...
# 955  2005   India                   24.7                         10.6
# 956  2005   India                   34.8                         15.8
# 979  2016   India                   16.4                          6.7
# 981  2005   India                   17.4                          2.0
# 995  2019   India                   23.6                          8.0
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %% [markdown]
# Temperature > 30

# %%
df[df["Avg Temperature (Â°C)"] > 30]
# Out:
#      Year       Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 1    2019           USA                   31.0                          4.8
# 2    2014        France                   33.9                          2.8
# 5    2020         China                   32.3                          1.4
# 6    2006     Argentina                   30.7                         11.6
# 7    2018  South Africa                   33.9                          6.0
# ..    ...           ...                    ...                          ...
# 973  2019            UK                   31.2                         16.3
# 987  2018         Japan                   34.0                          7.2
# 990  2004        Canada                   34.2                          0.8
# 993  2003  South Africa                   30.2                          8.5
# 994  2018     Australia                   34.5                         14.6
#
# ...

# %% [markdown]
# CO2 Emissions > 10

# %%
df[df['CO2 Emissions (Tons/Capita)']>10]
# Out:
#      Year       Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 6    2006     Argentina                   30.7                         11.6
# 8    2022            UK                   27.8                         16.6
# 11   2023  South Africa                   14.6                         14.7
# 12   2020        Brazil                   26.7                         12.2
# 14   2007       Germany                   11.0                         17.6
# ..    ...           ...                    ...                          ...
# 985  2010        Brazil                   17.6                         16.0
# 986  2007     Indonesia                    5.8                         17.7
# 994  2018     Australia                   34.5                         14.6
# 998  2016     Australia                   21.0                         14.9
# 999  2011       Germany                   24.1                         17.3
#
# ...

# %% [markdown]
# **Grouping**

# %% [markdown]
# Country Wise Temperature

# %%
df.groupby("Country")["Avg Temperature (Â°C)"].mean()
# Out:
# Country
# Argentina       19.298507
# Australia       19.449123
# Brazil          20.835821
# Canada          20.011940
# China           20.282090
# France          19.383333
# Germany         20.288525
# India           19.764286
# Indonesia       18.918667
# Japan           20.453968
# Mexico          20.696364
# Russia          20.718919
# South Africa    20.738356
# UK              18.490769
# USA             19.049315
# Name: Avg Temperature (Â°C), dtype: float64

# %% [markdown]
# Country Wise CO2

# %%
df.groupby("Country")["CO2 Emissions (Tons/Capita)"].sum()
# Out:
# Country
# Argentina       700.0
# Australia       507.3
# Brazil          726.2
# Canada          677.6
# China           726.0
# France          723.8
# Germany         602.7
# India           748.6
# Indonesia       826.6
# Japan           690.5
# Mexico          514.1
# Russia          663.6
# South Africa    702.1
# UK              822.3
# USA             794.4
# Name: CO2 Emissions (Tons/Capita), dtype: float64

# %% [markdown]
# Year Wise Temperature

# %%
df.groupby("Year")["Avg Temperature (Â°C)"].mean()
# Out:
# Year
# 2000    20.501887
# 2001    20.117073
# 2002    21.433333
# 2003    18.219512
# 2004    18.804000
# 2005    19.532432
# 2006    19.805128
# 2007    20.562500
# 2008    19.144444
# 2009    19.730303
# 2010    17.963333
# 2011    18.856818
# 2012    17.569048
# 2013    18.829032
# 2014    20.834091
# 2015    19.916279
# 2016    21.160784
# 2017    19.478125
# 2018    23.250000
# 2019    20.402500
# 2020    19.044186
# 2021    20.076087
# 2022    18.960000
# 2023    21.107143
# Name: Avg Temperature (Â°C), dtype: float64

# %% [markdown]
# **Sorting**

# %% [markdown]
# Highest Temperature

# %%
df.sort_values("Avg Temperature (Â°C)",ascending=False)
# Out:
#      Year       Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 400  2014        Brazil                   34.9                         17.4
# 909  2005         India                   34.9                          7.8
# 140  2008         China                   34.8                         19.8
# 956  2005         India                   34.8                         15.8
# 631  2000  South Africa                   34.8                          8.6
# ..    ...           ...                    ...                          ...
# 952  2020        France                    5.1                          8.5
# 412  2014            UK                    5.0                         17.0
# 488  2001  South Africa                    5.0                          4.0
# 33   2014  South Africa                    5.0                          1.1
# 974  2010        Brazil                    5.0                         15.8
#
# ...

# %% [markdown]
# Highest CO2

# %%
df.sort_values("CO2 Emissions (Tons/Capita)",ascending=False)
# Out:
#      Year    Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 425  2012      China                   12.7                         20.0
# 707  2021         UK                   17.1                         20.0
# 237  2015     Brazil                   28.9                         20.0
# 889  2023     France                   31.9                         19.9
# 312  2007  Argentina                    7.7                         19.9
# ..    ...        ...                    ...                          ...
# 336  2015        USA                   28.8                          0.6
# 856  2018     Brazil                    9.8                          0.5
# 110  2009    Germany                    6.3                          0.5
# 613  2011         UK                   19.6                          0.5
# 314  2002        USA                   17.0                          0.5
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %% [markdown]
# **Aggregations**

# %% [markdown]
# Minimum

# %%
df['Avg Temperature (Â°C)'].min()
# Out:
# 5.0

# %% [markdown]
# Maximum

# %%
df['Avg Temperature (Â°C)'].max()
# Out:
# 34.9

# %% [markdown]
# Mean

# %%
df['Avg Temperature (Â°C)'].mean()
# Out:
# np.float64(19.8831)

# %% [markdown]
# Median

# %%
df['Avg Temperature (Â°C)'].median()
# Out:
# 20.1

# %% [markdown]
# Mode

# %%
df['Avg Temperature (Â°C)'].mode()
# Out:
# 0    11.8
# Name: Avg Temperature (Â°C), dtype: float64

# %% [markdown]
# Variance

# %%
df['Avg Temperature (Â°C)'].var()
# Out:
# 72.9810854754756

# %% [markdown]
# **Sovle 20 Queries**

# %%
df['Avg Temperature (Â°C)'].max()
# Out:
# 34.9

# %%
df['Avg Temperature (Â°C)'].min()
# Out:
# 5.0

# %%
df['CO2 Emissions (Tons/Capita)'].max()
# Out:
# 20.0

# %%
df['CO2 Emissions (Tons/Capita)'].min()
# Out:
# 0.5

# %%
df['CO2 Emissions (Tons/Capita)'].mean()
# Out:
# np.float64(10.425799999999999)

# %%
df.groupby('Country')['CO2 Emissions (Tons/Capita)'].sum()
# Out:
# Country
# Argentina       700.0
# Australia       507.3
# Brazil          726.2
# Canada          677.6
# China           726.0
# France          723.8
# Germany         602.7
# India           748.6
# Indonesia       826.6
# Japan           690.5
# Mexico          514.1
# Russia          663.6
# South Africa    702.1
# UK              822.3
# USA             794.4
# Name: CO2 Emissions (Tons/Capita), dtype: float64

# %%
df.groupby('Country')['Avg Temperature (Â°C)'].mean()
# Out:
# Country
# Argentina       19.298507
# Australia       19.449123
# Brazil          20.835821
# Canada          20.011940
# China           20.282090
# France          19.383333
# Germany         20.288525
# India           19.764286
# Indonesia       18.918667
# Japan           20.453968
# Mexico          20.696364
# Russia          20.718919
# South Africa    20.738356
# UK              18.490769
# USA             19.049315
# Name: Avg Temperature (Â°C), dtype: float64

# %%
df['Rainfall (mm)'].mean()
# Out:
# np.float64(1738.761)

# %%
df['Population'].max()
# Out:
# 1397016073

# %%
df['Forest Area (%)'].mean()
# Out:
# np.float64(40.572)

# %%
df['Renewable Energy (%)'].max()
# Out:
# 50.0

# %%
df[df['Country']=='India']
# Out:
#      Year Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 15   2023   India                   31.0                         17.6
# 22   2005   India                    7.7                          6.1
# 25   2000   India                   20.9                         15.9
# 46   2003   India                   18.9                         19.0
# 52   2019   India                   27.7                          5.1
# ..    ...     ...                    ...                          ...
# 955  2005   India                   24.7                         10.6
# 956  2005   India                   34.8                         15.8
# 979  2016   India                   16.4                          6.7
# 981  2005   India                   17.4                          2.0
# 995  2019   India                   23.6                          8.0
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df[df['Country']=="USA"]
# Out:
#      Year Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 1    2019     USA                   31.0                          4.8
# 13   2003     USA                   27.4                          1.8
# 27   2021     USA                   28.9                         13.3
# 31   2015     USA                   10.6                         14.9
# 41   2006     USA                   14.8                          9.6
# ..    ...     ...                    ...                          ...
# 944  2005     USA                   27.1                         12.0
# 947  2023     USA                   12.6                          1.1
# 950  2004     USA                    8.2                         14.4
# 970  2023     USA                    6.8                         17.5
# 984  2014     USA                    5.5                         10.7
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df.groupby('Year')['CO2 Emissions (Tons/Capita)'].mean()
# Out:
# Year
# 2000    11.224528
# 2001     9.929268
# 2002     9.933333
# 2003    11.085366
# 2004    10.000000
# 2005     8.537838
# 2006    10.497436
# 2007    10.335000
# 2008    10.375000
# 2009    10.363636
# 2010     9.873333
# 2011     9.809091
# 2012    10.640476
# 2013    11.135484
# 2014    11.409091
# 2015     9.667442
# 2016    10.398039
# 2017     8.234375
# 2018    10.443478
# 2019     9.812500
# 2020    10.246512
# 2021    11.521739
# 2022    12.326667
# 2023    11.402381
# Name: CO2 Emissions (Tons/Capita), dtype: float64

# %%
df.groupby('Year')["Avg Temperature (Â°C)"].mean()
# Out:
# Year
# 2000    20.501887
# 2001    20.117073
# 2002    21.433333
# 2003    18.219512
# 2004    18.804000
# 2005    19.532432
# 2006    19.805128
# 2007    20.562500
# 2008    19.144444
# 2009    19.730303
# 2010    17.963333
# 2011    18.856818
# 2012    17.569048
# 2013    18.829032
# 2014    20.834091
# 2015    19.916279
# 2016    21.160784
# 2017    19.478125
# 2018    23.250000
# 2019    20.402500
# 2020    19.044186
# 2021    20.076087
# 2022    18.960000
# 2023    21.107143
# Name: Avg Temperature (Â°C), dtype: float64

# %%
df['Extreme Weather Events'].max()
# Out:
# 14

# %%
df.sort_values('Rainfall (mm)',ascending=False)
# Out:
#      Year       Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 744  2008        Canada                   27.4                         13.5
# 875  2021  South Africa                    7.8                         12.5
# 627  2018         Japan                   32.8                         12.6
# 817  2009     Indonesia                   10.5                         18.9
# 816  2022        Mexico                   34.0                          6.8
# ..    ...           ...                    ...                          ...
# 358  2000        Canada                   14.4                          1.2
# 767  2008        France                    6.5                         11.0
# 129  2000           USA                   28.0                         17.8
# 991  2005     Indonesia                   29.8                          6.3
# 749  2022  South Africa                   34.4                          9.0
#
# ...

# %%
df.sort_values('Population',ascending=False)
# Out:
#      Year    Country  Avg Temperature (Â°C)  CO2 Emissions (Tons/Capita)  \
# 700  2007     Russia                   24.9                         12.4
# 37   2019     Canada                   21.8                          1.0
# 341  2016     Brazil                   28.1                         16.9
# 622  2017     Canada                   16.3                          2.3
# 344  2020     Brazil                   14.1                          3.3
# ..    ...        ...                    ...                          ...
# 853  2002  Indonesia                    5.5                         11.9
# 575  2003      India                    6.4                          9.4
# 251  2017     Brazil                    7.7                         18.2
# 732  2021      Japan                   16.1                          3.6
# 838  2010      China                   30.9                         12.1
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                  Year  Avg Temperature (Â°C)  \
# Year                         1.000000               0.020954
# Avg Temperature (Â°C)        0.020954               1.000000
# CO2 Emissions (Tons/Capita)  0.041018               0.012323
# Sea Level Rise (mm)          0.035433               0.059005
# Rainfall (mm)               -0.013638              -0.004532
# Population                   0.071744               0.003550
# Renewable Energy (%)         0.023826              -0.065472
# Extreme Weather Events      -0.021620               0.034951
# Forest Area (%)             -0.041327              -0.017027
#
#                              CO2 Emissions (Tons/Capita)  Sea Level Rise (mm)  \
# Year                                            0.041018             0.035433
# Avg Temperature (Â°C)                           0.012323             0.059005
# CO2 Emissions (Tons/Capita)                     1.000000            -0.038815
# ...

# %%
df['Sea Level Rise (mm)'].mean()
# Out:
# np.float64(3.0096000000000003)

# %%
df['Renewable Energy (%)'].mean()
# Out:
# np.float64(27.3005)

# %% [markdown]
# **Data Visualizatin**

# %% [markdown]
# Line Chart

# %%
a=plt.figure(figsize=(10,5))
a

# %%
b=plt.plot(df['Year'],df['Avg Temperature (Â°C)'])
b

# %%
c= plt.title('Temperature in the year')
c
# Out:
# Text(0.5, 1.0, 'Temperature in the year')

# %%
d=plt.show()
d

# %% [markdown]
# Bar Chart

# %%
df.groupby('Country')['CO2 Emissions (Tons/Capita)'].sum().plot(kind='bar')
plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(df['Avg Temperature (Â°C)'])
plt.show()

# %% [markdown]
# **Machine Learning (Linear Regression)**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=df[['CO2 Emissions (Tons/Capita)']]
y=df['Avg Temperature (Â°C)']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
pred=model.predict(x_test)
print(pred[:10])
# Out:
# [20.03599787 19.77674098 19.74028298 19.82940253 20.09473576 19.74635931
#  19.83750431 19.99346354 19.90636942 19.97928542]
